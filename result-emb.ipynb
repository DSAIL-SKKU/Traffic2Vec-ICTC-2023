# %%
import pandas as pd
import numpy as np
import torch

# %%
types = ['interactive', 'bulk', 'video', 'web']
models = ['CWGAN', 'GMMN', 'RCGAN', 'RCWGAN', 'SigCWGAN', 'TimeGAN']

# %%
for t in types:
    if t == 'interactive':
        df = pd.read_csv(f'~/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/{t}_emb/traffic/summary.csv', decimal=',', sep=';')
        df['type'] = t
        all_df = df.copy()
    else:
        df = pd.read_csv(f'~/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/{t}_emb/traffic/summary.csv', decimal=',', sep=';')
        df['type'] = t
        all_df = pd.concat([all_df, df])

# %%
all_df = all_df.reset_index(drop=True)
all_df
# Out:
#     model_id    seed  r2_tstr  r2_trtr  predictive_score  abs_metric  \
# 0    TimeGAN  seed=0  0.72059  0.90043           0.17984     0.22131
# 1       GMMN  seed=0  0.76543  0.90043           0.13499     0.23083
# 2     RCWGAN  seed=0  0.84565  0.90043           0.05477     0.21485
# 3   SigCWGAN  seed=0  0.88644  0.90043           0.01398     0.19048
# 4      RCGAN  seed=0  0.68083  0.90043           0.21960     0.22593
# 5    TimeGAN  seed=0  0.86837  0.95976           0.09139     0.29887
# 6       GMMN  seed=0  0.80284  0.95976           0.15692     0.30568
# 7     RCWGAN  seed=0  0.91870  0.95976           0.04106     0.28704
# 8   SigCWGAN  seed=0  0.94159  0.95976           0.01817     0.27703
# 9      RCGAN  seed=0  0.85494  0.95976           0.10482     0.29865
# 10   TimeGAN  seed=0  0.67994  0.89616           0.21622     0.51840
# 11      GMMN  seed=0  0.75885  0.89616           0.13731     0.53178
# 12    RCWGAN  seed=0  0.83300  0.89616           0.06315     0.52117
# ...

# %%
for t in types:
    if t == 'interactive':
        df = pd.read_csv(f'~/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/{t}_emb/traffic/summaryNope.csv', decimal=',', sep=';')
        df['type'] = t
        all_df2 = df.copy()
    else:
        df = pd.read_csv(f'~/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/{t}_emb/traffic/summaryNope.csv', decimal=',', sep=';')
        df['type'] = t
        all_df2 = pd.concat([all_df2, df])

# %%
all_df2 = all_df2.reset_index(drop=True)
all_df2
# Out:
#     model_id    seed  discriminative  predictive         type
# 0    TimeGAN  seed=0         0.09658        0.58  interactive
# 1       GMMN  seed=0         0.09291        0.54  interactive
# 2     RCWGAN  seed=0         0.05868        0.26  interactive
# 3   SigCWGAN  seed=0         0.11614        0.16  interactive
# 4      RCGAN  seed=0         0.16015        0.59  interactive
# 5    TimeGAN  seed=0         0.41011        0.37         bulk
# 6       GMMN  seed=0         0.10393        0.33         bulk
# 7     RCWGAN  seed=0         0.30618        0.36         bulk
# 8   SigCWGAN  seed=0         0.42978        0.17         bulk
# 9      RCGAN  seed=0         0.18820        0.39         bulk
# 10   TimeGAN  seed=0         0.14045        0.50        video
# 11      GMMN  seed=0         0.16854        0.44        video
# 12    RCWGAN  seed=0         0.06180        0.22        video
# 13  SigCWGAN  seed=0         0.04494        0.18        video
# ...

# %%
all_df['discriminative'] = all_df2['discriminative']
all_df['predictive'] = all_df2['predictive']

# %%
all_df
# Out:
#     model_id    seed  r2_tstr  r2_trtr  predictive_score  abs_metric  \
# 0    TimeGAN  seed=0  0.72059  0.90043           0.17984     0.22131
# 1       GMMN  seed=0  0.76543  0.90043           0.13499     0.23083
# 2     RCWGAN  seed=0  0.84565  0.90043           0.05477     0.21485
# 3   SigCWGAN  seed=0  0.88644  0.90043           0.01398     0.19048
# 4      RCGAN  seed=0  0.68083  0.90043           0.21960     0.22593
# 5    TimeGAN  seed=0  0.86837  0.95976           0.09139     0.29887
# 6       GMMN  seed=0  0.80284  0.95976           0.15692     0.30568
# 7     RCWGAN  seed=0  0.91870  0.95976           0.04106     0.28704
# 8   SigCWGAN  seed=0  0.94159  0.95976           0.01817     0.27703
# 9      RCGAN  seed=0  0.85494  0.95976           0.10482     0.29865
# 10   TimeGAN  seed=0  0.67994  0.89616           0.21622     0.51840
# 11      GMMN  seed=0  0.75885  0.89616           0.13731     0.53178
# 12    RCWGAN  seed=0  0.83300  0.89616           0.06315     0.52117
# ...

# %%
all_df.to_csv('/home/dsail/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/traffic_all_result_emb.csv', index = None)

# %%
all_df.groupby('model_id').mean()
# Out:
# /tmp/ipykernel_1913041/3002946788.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_df.groupby('model_id').mean()
#            r2_tstr   r2_trtr  predictive_score  abs_metric  acf_id_lag=1  \
# model_id
# GMMN      0.757460  0.919272          0.161810    0.382265      0.101720
# RCGAN     0.711973  0.919272          0.207297    0.374020      0.147677
# RCWGAN    0.870495  0.919272          0.048770    0.365875      0.065122
# SigCWGAN  0.903402  0.919272          0.015867    0.348793      0.026597
# TimeGAN   0.746285  0.919272          0.172985    0.372115      0.119700
#
#           kurtosis      skew  cross_correl  sig_w1_metric  discriminative  \
# model_id
# GMMN      0.631925  0.178570      6.016793       0.261190        0.110285
# ...

# %%
all_df.groupby('model_id').mean().to_csv('/home/dsail/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/traffic_modelby_emb.csv', index = None)
# Out:
# /tmp/ipykernel_1913041/1770044735.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_df.groupby('model_id').mean().to_csv('/home/dsail/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/traffic_modelby_emb.csv', index = None)

# %%
all_df.groupby('type').mean()
# Out:
# /tmp/ipykernel_1913041/1704854406.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_df.groupby('type').mean()
#               r2_tstr  r2_trtr  predictive_score  abs_metric  acf_id_lag=1  \
# type
# bulk         0.877288  0.95976          0.082472    0.293454      0.059666
# interactive  0.779788  0.90043          0.120636    0.216680      0.092802
# video        0.757160  0.89616          0.138996    0.521040      0.097790
# web          0.777456  0.92074          0.143280    0.443280      0.118396
#
#              kurtosis      skew  cross_correl  sig_w1_metric  discriminative  \
# type
# bulk         0.340572  0.074060      3.443590       0.238454        0.287640
# interactive  0.249270  0.326164      5.439942       0.208890        0.104892
# ...

# %%
all_df.groupby('type').mean().to_csv('/home/dsail/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/traffic_typeby_emb.csv', index = None)
# Out:
# /tmp/ipykernel_1913041/1902870352.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_df.groupby('type').mean().to_csv('/home/dsail/migyeongk/기초연구실/minji/github/Conditional-Sig-Wasserstein-GANs/numerical_results/traffic_typeby_emb.csv', index = None)
